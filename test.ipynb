# %%
from rdkit import Chem
from rdkit.Chem import Draw, AllChem
from rdkit.Chem.Draw import rdMolDraw2D

# %%
smiles = 'CC1=C(C=C(C=C1)NC(=O)C2=CC=C(C=C2)CN3CCN(CC3)C)NC4=NC=CC(=N4)C5=CN=CC=C5'

# %%
def smiles_to_svg(smiles): 
    mol = Chem.MolFromSmiles(smiles)
    AllChem.Compute2DCoords(mol)
    d2d = rdMolDraw2D.MolDraw2DSVG(250, 200)
    d2d.DrawMolecule(mol)
    d2d.FinishDrawing()
    svg_text = d2d.GetDrawingText()
    return svg_text

# %%
from urllib.parse import quote

def svg_to_datauri(svg_text):
    if not isinstance(svg_text, str) or not svg_text.strip():
        return None
    return 'data:image/svg+xml;utf8,' + quote(svg_text)

# %%
text = smiles_to_svg(smiles)
datauri = svg_to_datauri(text)

# %%
datauri
# Out:
# 'data:image/svg+xml;utf8,%3C%3Fxml%20version%3D%271.0%27%20encoding%3D%27iso-8859-1%27%3F%3E%0A%3Csvg%20version%3D%271.1%27%20baseProfile%3D%27full%27%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20xmlns%3D%27http%3A//www.w3.org/2000/svg%27%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20xmlns%3Ardkit%3D%27http%3A//www.rdkit.org/xml%27%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20xmlns%3Axlink%3D%27http%3A//www.w3.org/1999/xlink%27%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20xml%3Aspace%3D%27preserve%27%0Awidth%3D%27250px%27%20height%3D%27200px%27%20viewBox%3D%270%200%20250%20200%27%3E%0A%3C%21--%20END%20OF%20HEADER%20--%3E%0A%3Crect%20style%3D%27opacity%3A1.0%3Bfill%3A%23FFFFFF%3Bstroke%3Anone%27%20width%3D%27250.0%27%20height%3D%27200.0%27%20x%3D%270.0%27%20y%3D%270.0%27%3E%20%3C/rect%3E%0A%3Cpath%20class%3D%27bond-0%20atom-0%20atom-1%27%20d%3D%27M%2079.3%2C144.3%20L%2090.4%2C134.7%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-1%20atom-1%20atom-2%27%20d%3D%27M%2090.4%2C134.7%20L%2087.6%2C120.2%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-1%20atom-1%20atom-2%27%20d%3D%27M%2092.3%2C133.0%20L%2090.0%2C121.1%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-2%20atom-2%20atom-3%27%20d%3D%27M%2087.6%2C120.2%20L%2098.7%2C110.6%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-3%20atom-3%20atom-4%27%20d%3D%27M%2098.7%2C110.6%20L%20112.6%2C115.4%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-3%20atom-3%20atom-4%27%20d%3D%27M%2099.2%2C113.1%20L%20110.6%2C117.1%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-4%20atom-4%20atom-5%27%20d%3D%27M%20112.6%2C115.4%20L%20115.4%2C129.8%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-5%20atom-5%20atom-6%27%20d%3D%27M%20115.4%2C129.8%20L%20104.3%2C139.5%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-5%20atom-5%20atom-6%27%20d%3D%27M%20113.0%2C129.0%20L%20103.8%2C137.0%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-6%20atom-4%20atom-7%27%20d%3D%27M%20112.6%2C115.4%20L%20117.1%2C111.5%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%23000000%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-6%20atom-4%20atom-7%27%20d%3D%27M%20117.1%2C111.5%20L%20121.6%2C107.6%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstroke%3A%230000FF%3Bstroke-width%3A2.0px%3Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Amiter%3Bstroke-opacity%3A1%27%20/%3E%0A%3Cpath%20class%3D%27bond-7%20atom-7%20atom-8%27%20d%3D%27M%20125.8%2C106.5%20L%20131.6%2C108.5%27%20style%3D%27fill%3Anone%3Bfill-rule%3Aevenodd%3Bstro ...
